# %%
#importing essential libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Reading data
data = pd.read_csv('BostonHousing.csv')

# %%
data.shape
# Out:
# (506, 14)

# %%
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# crim       506 non-null float64
# zn         506 non-null float64
# indus      506 non-null float64
# chas       506 non-null int64
# nox        506 non-null float64
# rm         506 non-null float64
# age        506 non-null float64
# dis        506 non-null float64
# rad        506 non-null int64
# tax        506 non-null int64
# ptratio    506 non-null float64
# b          506 non-null float64
# lstat      506 non-null float64
# medv       506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.4 KB

# %%
data.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#There are no missing values in the data
data.apply(lambda x: sum(x.isnull()))
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
corr = data.select_dtypes(include = ['float64', 'int64']).corr()
plt.figure(figsize=(12, 12))
sns.heatmap(corr, vmax=1, square=True , annot = True)
plt.show()

# %%
#As per the corelation plot, we remove one of features from the pair that is highly correlated.
data.drop(['age','dis','tax'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (506, 11)

# %%
#Data Visualizations

# %%
x=data.crim
y=data.medv
plt.scatter(x,y)
plt.title('crime rate vs target')
plt.xlabel('crime')
plt.ylabel('target')

# %%
x=data.zn
y=data.medv
plt.scatter(x,y)
plt.title('zn vs target')
plt.xlabel('zn')
plt.ylabel('target')

# %%
x=data.indus
y=data.medv
plt.scatter(x,y)
plt.title('indus vs target')
plt.xlabel('indus')
plt.ylabel('target')

# %%
sns.barplot(x='chas', y='medv',data= data)

# %%
x=data.nox
y=data.medv
plt.scatter(x,y)
plt.title('nox vs target')
plt.xlabel('nox')
plt.ylabel('target')

# %%
x=data.rm
y=data.medv
plt.scatter(x,y)
plt.title('rm vs target')
plt.xlabel('rm')
plt.ylabel('target')

# %%
x=data.rad
y=data.medv
plt.scatter(x,y)
plt.title('rad vs target')
plt.xlabel('rad')
plt.ylabel('target')

# %%
x=data.ptratio
y=data.medv
plt.scatter(x,y)
plt.title('ptratio vs target')
plt.xlabel('ptratio')
plt.ylabel('target')

# %%
x=data.b
y=data.medv
plt.scatter(x,y)
plt.title('black vs target')
plt.xlabel('black')
plt.ylabel('target')

# %%
x=data.lstat
y=data.medv
plt.scatter(x,y)
plt.title('lstat vs target')
plt.xlabel('lstat')
plt.ylabel('target')

# %%
#According to the data visualization, we can now remove the features that do not contribute so much in predicting the target variable.
data.drop(['zn','indus','chas','nox','rad','b'], axis=1, inplace=True)

# %%
#So, we now see the reduced data
data.shape
# Out:
# (506, 5)

# %%
X=data.drop('medv',axis=1)
y=data['medv']

# %%
#performing the train test split
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(X_train,y_train)
pred=regr.predict(X_test)

# %%
plt.scatter(y_test,pred)

# %%
#The score isn't satisfactory,so we go for dimensionality reduction using PCA
from sklearn.metrics import r2_score
print r2_score(y_test,pred)
# Out:
# 0.668295288809

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test,pred)
# Out:
# 4.0337116579818497

# %%
#PCA

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(data)
scaler_data=scaler.transform(data)
scaler_data.shape
# Out:
# (506L, 5L)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(scaler_data)
train_pca=pca.transform(scaler_data)
train_pca.shape
# Out:
# (506L, 2L)

# %%
#The first component shows a variation of nearly 60%
print pca.explained_variance_ratio_
# Out:
# [ 0.58340572  0.16373787]

# %%
train_pcax= pd.DataFrame(train_pca)

# %%
X= train_pcax
y= data['medv']

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,y_train)
predn=regr.predict(X_test)

# %%
plt.scatter(y_test,predn)

# %%
#Reduced the mean square error
from sklearn import metrics
metrics.mean_absolute_error(y_test,predn)
# Out:
# 2.8336727751462751

# %%
#Improvised score
print r2_score(y_test,predn)
# Out:
# 0.83577028482
